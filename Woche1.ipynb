# %% [markdown]
# <a href="https://colab.research.google.com/github/LarissaLeist/programmier-uebungen/blob/main/Woche1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Programmieren für Laborexperimente**

# %% [markdown]
# Woche 1: Python Grundlagen I

# %% [markdown]
# **Erstes Programm**

# %%
print("Hallo Welt!")
# Out:
# Hallo Welt!

# %% [markdown]
# Ändern Sie den Text so, dass Ihr eigener Name ausgegeben wird.
# Mit Strg + Enter führen Sie die Zelle aus.

# %% [markdown]
# **Aufgabe 1: Variablen**

# %%
name = "Anna"
alter = 20
rt = 0.532

print(name)
print(alter)
print(type(rt))

# %% [markdown]
# Erstellen Sie drei Variablen:
#
# *   Ihren Namen
# *   Ihr Alter
# *   eine beliebige Zahl
#
# Geben Sie alle Werte aus.

# %%
# Ihr Code hier

# %% [markdown]
# **Aufgabe 2: Vorhersage**

# %%
x = 5
y = 3
print(x + y)

# %% [markdown]
# Was wird ausgegeben?
# Notieren Sie Ihre Antwort und überprüfen Sie sie anschließend.

# %% [markdown]
# **Aufgabe 3: Datentypen**

# %%
a = 10
b = "10"
c = 10.0

# %% [markdown]
# Bestimmen Sie den Datentyp der Variablen

# %% [markdown]
# **Aufgabe 4: String-Verarbeitung**

# %%
print("2" + "3")

# %% [markdown]
# Was wird ausgegeben?
#
# Überprüfen Sie Ihre Vermutung durch Ausführen des Codes.

# %% [markdown]
# **Aufgabe 5: Fehleranalyse**

# %%
name = Anna
print(name)

# %% [markdown]
# Warum funktioniert dieser Code nicht?
# Identifizieren Sie den Fehler und korrigieren Sie ihn.

# %% [markdown]
# **Aufgabe 6: Anwendung**

# %%
Schreiben Sie ein Programm, das:

Ihren Namen speichert
eine Begrüßung ausgibt
Erwartete Ausgabe (Beispiel):

Hallo Larissa!

# %%
# Ihr Code hier

# %% [markdown]
# **Zusatzaufgabe**

# %%
x = "5"
y = 2
print(x * y)

# %% [markdown]
# Was wird ausgegeben?
